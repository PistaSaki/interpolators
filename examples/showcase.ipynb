# %%
import numpy as np

import matplotlib.pylab as pl
# %matplotlib inline

# %%
from interpolators import Interpolator

# %%
f = Interpolator(
    params = [[-1, 0, 1, 2, 3]],
    values = np.array([1, 3, 2, 5, 4])
)

# %%
f.plot()
(f/2 + 1).plot()
